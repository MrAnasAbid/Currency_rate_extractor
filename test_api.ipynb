# %%
import os
import requests
from pandas import DataFrame, option_context
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv('EXCHANGE_RATE_API_KEY')

# %%
base_currency = "USD"
url_currency_rates = f"https://v6.exchangerate-api.com/v6/{api_key}/latest/{base_currency}"
req_currency = requests.get(url_currency_rates)

data = req_currency.json()

# Extract conversion rates and create DataFrame
conversion_rates = DataFrame(data['conversion_rates'].items(), columns=['Currency_Code', 'Rate'])

# Sort DataFrame by Rate in descending order
highest_rates = conversion_rates.sort_values(by="Rate", ascending=False).reset_index(drop=True)
highest_rates["date"] = data["time_last_update_utc"].split(" 00:")[0]
highest_rates.head()
# Out:
#   Currency_Code        Rate              date
# 0           LBP  89500.0000  Sun, 02 Jun 2024
# 1           IRR  42063.1818  Sun, 02 Jun 2024
# 2           VND  25469.2457  Sun, 02 Jun 2024
# 3           SLL  22504.0936  Sun, 02 Jun 2024
# 4           LAK  21655.8461  Sun, 02 Jun 2024

# %% [markdown]
# - Add country names from this site (quick scraping) https://www.foreignexchangelive.com/currency-codes-symbols/

# %%
url_currency_codes = f'https://v6.exchangerate-api.com/v6/{api_key}/codes'
req_codes = requests.get(url_currency_codes)
data_code = req_codes.json()
codes = DataFrame(data_code["supported_codes"], columns=["Currency_Code", "Currency_Name"])

# %%
import pandasql as ps
query = """
SELECT Currency_Code, Rate, Currency_Name, date
FROM highest_rates NATURAL JOIN codes
"""
result = ps.sqldf(query, locals())

# %%
with option_context('display.max_rows', None, 'display.max_columns', None):
    display(result)
# Out:
#     Currency_Code        Rate                            Currency_Name  \
# 0             LBP  89500.0000                           Lebanese Pound
# 1             IRR  42063.1818                             Iranian Rial
# 2             VND  25469.2457                          Vietnamese Đồng
# 3             SLL  22504.0936                     Sierra Leonean Leone
# 4             LAK  21655.8461                                  Lao Kip
# 5             IDR  16248.8365                        Indonesian Rupiah
# 6             SYP  12903.8830                             Syrian Pound
# 7             UZS  12668.2234                         Uzbekistani So'm
# 8             GNF   8584.4392                            Guinean Franc
# 9             PYG   7511.8283                       Paraguayan Guaraní
# 10            MGA   4445.6919                          Malagasy Ariary
# 11            KHR   4089.9089                           Cambodian Riel
# 12            COP   3867.8072                           Colombian Peso
# 13            UGX   3804.4520                         Ugandan Shilling
# 14            MNT   3380.2543                         Mongolian Tögrög
# 15            BIF   2861.8756                          Burundian Franc
# 16            CDF   2757.3592                          Congolese Franc
# 17            TZS   2597.9152                       Tanzanian Shilling
# 18            MMK   2101.5186                             Burmese Kyat
# 19            SSP   1749.5048                     South Sudanese Pound
# 20            MWK   1744.3498                          Malawian Kwacha
# 21            NGN   1443.2484                           Nigerian Naira
# 22            KRW   1380.7555                         South Korean Won
# 23            RWF   1312.8608                            Rwandan Franc
# 24            IQD   1310.8824                              Iraqi Dinar
# 25            CLP    916.7242                             Chilean Peso
# 26            ARS    864.7500                           Argentine Peso
# 27            AOA    863.4038                           Angolan Kwanza
# 28            XAF    604.9510                Central African CFA Franc
# 29            XOF    604.9510                   West African CFA franc
# 30            SOS    571.5344                          Somali Shilling
# 31            CRC    520.9293                        Costa Rican Colon
# 32            SDG    509.3455                           Sudanese Pound
# 33            KMF    453.7133                           Comorian Franc
# 34            KZT    447.2582                        Kazakhstani Tenge
# 35            AMD    387.7945                            Armenian Dram
# 36            HUF    358.8755                         Hungarian Forint
# 37            LKR    301.7330                          Sri Lanka Rupee
# 38            PKR    278.2309                          Pakistani Rupee
# 39            YER    250.2722                              Yemeni Rial
# 40            GYD    209.2981                          Guyanese Dollar
# 41            LRD    193.9011                          Liberian Dollar
# 42            DJF    177.7210                         Djiboutian Franc
# 43            JPY    157.1512                             Japanese Yen
# 44            JMD    155.7124                          Jamaican Dollar
# 45            ISK    137.3516                          Icelandic Króna
# 46            DZD    134.7367                           Algerian Dinar
# 47            NPR    133.4909                           Nepalese Rupee
# 48            HTG    132.6077                           Haitian Gourde
# 49            KES    130.4943                          Kenyan Shilling
# 50            VUV    119.3146                             Vanuatu Vatu
# 51            BDT    117.4028                         Bangladeshi Taka
# 52            XPF    110.0530                                CFP Franc
# 53            RSD    107.9775                            Serbian Dinar
# 54            CVE    101.6910                      Cape Verdean Escudo
# 55            ALL     93.3128                             Albanian Lek
# 56            RUB     90.1109                            Russian Ruble
# 57            KGS     87.8558                          Kyrgyzstani Som
# 58            INR     83.4319                             Indian Rupee
# 59            BTN     83.4318                       Bhutanese Ngultrum
# 60            AFN     71.8936                           Afghan Afghani
# 61            GMD     65.4016                           Gambian Dalasi
# 62            MZN     63.8582                       Mozambican Metical
# 63            DOP     59.0536                           Dominican Peso
# 64            PHP     58.5634                          Philippine Peso
# 65            ETB     57.5453                           Ethiopian Birr
# 66            MKD     56.7378                         Macedonian Denar
# 67            EGP     47.2704                           Egyptian Pound
# 68            MUR     46.2804                          Mauritian Rupee
# 69            UAH     40.5305                        Ukrainian Hryvnia
# 70            MRU     39.3518                      Mauritanian Ouguiya
# 71            UYU     38.5951                           Uruguayan Peso
# 72            NIO     36.8397                       Nicaraguan Córdoba
# 73            THB     36.7584                                Thai Baht
# 74            VES     36.5344              Venezuelan Bolívar Soberano
# 75            TWD     32.4750                        New Taiwan Dollar
# 76            SRD     32.3621                        Surinamese Dollar
# 77            TRY     32.2396                             Turkish Lira
# 78            ZMW     26.4746                           Zambian Kwacha
# 79            HNL     24.7173                         Honduran Lempira
# 80            CUP     24.0000                               Cuban Peso
# 81            CZK     22.7852                             Czech Koruna
# 82            STN     22.5949              São Tomé and Príncipe Dobra
# 83            SLE     22.5041                     Sierra Leonean Leone
# 84            NAD     18.7748                          Namibian Dollar
# 85            LSL     18.7748                             Lesotho Loti
# 86            SZL     18.7748                       Eswatini Lilangeni
# 87            ZAR     18.7625                       South African Rand
# 88            MDL     17.6975                             Moldovan Leu
# 89            MXN     17.0137                             Mexican Peso
# 90            MVR     15.4504                        Maldivian Rufiyaa
# 91            GHS     15.0473                            Ghanaian Cedi
# 92            ERN     15.0000                           Eritrean Nakfa
# 93            BWP     13.6455                            Botswana Pula
# 94            SCR     13.5673                        Seychellois Rupee
# 95            ZWL     13.3177                        Zimbabwean Dollar
# 96            TJS     10.8139                       Tajikistani Somoni
# 97            SEK     10.5336                            Swedish Krona
# 98            NOK     10.5007                          Norwegian Krone
# 99            MAD      9.9500                          Moroccan Dirham
# 100           SBD      8.4697                   Solomon Islands Dollar
# 101           MOP      8.0535                          Macanese Pataca
# 102           HKD      7.8189                         Hong Kong Dollar
# 103           GTQ      7.7702                       Guatemalan Quetzal
# 104           CNY      7.2576                         Chinese Renminbi
# 105           HRK      6.9486                            Croatian Kuna
# 106           BOB      6.9279                       Bolivian Boliviano
# 107           DKK      6.8793                             Danish Krone
# 108           FOK      6.8793                            Faroese Króna
# 109           TTD      6.7736               Trinidad and Tobago Dollar
# 110           BRL      5.2026                           Brazilian Real
# 111           LYD      4.8408                             Libyan Dinar
# 112           MYR      4.7067                        Malaysian Ringgit
# 113           RON      4.5878                             Romanian Leu
# 114           PLN      3.9373                             Polish Złoty
# 115           PGK      3.8560                   Papua New Guinean Kina
# 116           PEN      3.7586                             Peruvian Sol
# 117           SAR      3.7500                              Saudi Riyal
# 118           ILS      3.7099                       Israeli New Shekel
# 119           AED      3.6725                               UAE Dirham
# 120           QAR      3.6400                             Qatari Riyal
# 121           TMT      3.4998                       Turkmenistan Manat
# 122           BYN      3.2578                         Belarusian Ruble
# 123           TND      3.1106                           Tunisian Dinar
# 124           GEL      2.7938                            Georgian Lari
# 125           WST      2.7284                              Samoan Tālā
# 126           XCD      2.7000                    East Caribbean Dollar
# 127           TOP      2.3345                           Tongan Paʻanga
# 128           FJD      2.2299                              Fiji Dollar
# 129           BZD      2.0000                            Belize Dollar
# 130           BBD      2.0000                          Barbados Dollar
# 131           BAM      1.8037  Bosnia and Herzegovina Convertible Mark
# 132           BGN      1.8037                            Bulgarian Lev
# 133           AWG      1.7900                            Aruban Florin
# 134           ANG      1.7900            Netherlands Antillian Guilder
# 135           AZN      1.7002                        Azerbaijani Manat
# 136           NZD      1.6289                       New Zealand Dollar
# 137           KID      1.5039                          Kiribati Dollar
# 138           AUD      1.5039                        Australian Dollar
# 139           TVD      1.5039                          Tuvaluan Dollar
# 140           CAD      1.3631                          Canadian Dollar
# 141           BND      1.3514                            Brunei Dollar
# 142           SGD      1.3514                         Singapore Dollar
# 143           BMD      1.0000                         Bermudian Dollar
# 144           BSD      1.0000                          Bahamian Dollar
# 145           USD      1.0000                     United States Dollar
# 146           PAB      1.0000                        Panamanian Balboa
# 147           EUR      0.9222                                     Euro
# 148           CHF      0.9030                              Swiss Franc
# 149           KYD      0.8333                    Cayman Islands Dollar
# 150           FKP      0.7856                   Falkland Islands Pound
# 151           GBP      0.7856                           Pound Sterling
# 152           SHP      0.7856                       Saint Helena Pound
# 153           GGP      0.7856                           Guernsey Pound
# 154           GIP      0.7856                          Gibraltar Pound
# 155           IMP      0.7856                               Manx Pound
# 156           JEP      0.7856                             Jersey Pound
# 157           XDR      0.7552                   Special Drawing Rights
# 158           JOD      0.7090                          Jordanian Dinar
# 159           OMR      0.3845                               Omani Rial
# 160           BHD      0.3760                           Bahraini Dinar
# 161           KWD      0.3069                            Kuwaiti Dinar
#
#                  date
# 0    Sun, 02 Jun 2024
# 1    Sun, 02 Jun 2024
# 2    Sun, 02 Jun 2024
# 3    Sun, 02 Jun 2024
# 4    Sun, 02 Jun 2024
# 5    Sun, 02 Jun 2024
# 6    Sun, 02 Jun 2024
# 7    Sun, 02 Jun 2024
# 8    Sun, 02 Jun 2024
# 9    Sun, 02 Jun 2024
# 10   Sun, 02 Jun 2024
# 11   Sun, 02 Jun 2024
# 12   Sun, 02 Jun 2024
# 13   Sun, 02 Jun 2024
# 14   Sun, 02 Jun 2024
# 15   Sun, 02 Jun 2024
# 16   Sun, 02 Jun 2024
# 17   Sun, 02 Jun 2024
# 18   Sun, 02 Jun 2024
# 19   Sun, 02 Jun 2024
# 20   Sun, 02 Jun 2024
# 21   Sun, 02 Jun 2024
# 22   Sun, 02 Jun 2024
# 23   Sun, 02 Jun 2024
# 24   Sun, 02 Jun 2024
# 25   Sun, 02 Jun 2024
# 26   Sun, 02 Jun 2024
# 27   Sun, 02 Jun 2024
# 28   Sun, 02 Jun 2024
# 29   Sun, 02 Jun 2024
# 30   Sun, 02 Jun 2024
# 31   Sun, 02 Jun 2024
# 32   Sun, 02 Jun 2024
# 33   Sun, 02 Jun 2024
# 34   Sun, 02 Jun 2024
# 35   Sun, 02 Jun 2024
# 36   Sun, 02 Jun 2024
# 37   Sun, 02 Jun 2024
# 38   Sun, 02 Jun 2024
# 39   Sun, 02 Jun 2024
# 40   Sun, 02 Jun 2024
# 41   Sun, 02 Jun 2024
# 42   Sun, 02 Jun 2024
# 43   Sun, 02 Jun 2024
# 44   Sun, 02 Jun 2024
# 45   Sun, 02 Jun 2024
# 46   Sun, 02 Jun 2024
# 47   Sun, 02 Jun 2024
# 48   Sun, 02 Jun 2024
# 49   Sun, 02 Jun 2024
# 50   Sun, 02 Jun 2024
# 51   Sun, 02 Jun 2024
# 52   Sun, 02 Jun 2024
# 53   Sun, 02 Jun 2024
# 54   Sun, 02 Jun 2024
# 55   Sun, 02 Jun 2024
# 56   Sun, 02 Jun 2024
# 57   Sun, 02 Jun 2024
# 58   Sun, 02 Jun 2024
# 59   Sun, 02 Jun 2024
# 60   Sun, 02 Jun 2024
# 61   Sun, 02 Jun 2024
# 62   Sun, 02 Jun 2024
# 63   Sun, 02 Jun 2024
# 64   Sun, 02 Jun 2024
# 65   Sun, 02 Jun 2024
# 66   Sun, 02 Jun 2024
# 67   Sun, 02 Jun 2024
# 68   Sun, 02 Jun 2024
# 69   Sun, 02 Jun 2024
# 70   Sun, 02 Jun 2024
# 71   Sun, 02 Jun 2024
# 72   Sun, 02 Jun 2024
# 73   Sun, 02 Jun 2024
# 74   Sun, 02 Jun 2024
# 75   Sun, 02 Jun 2024
# 76   Sun, 02 Jun 2024
# 77   Sun, 02 Jun 2024
# 78   Sun, 02 Jun 2024
# 79   Sun, 02 Jun 2024
# 80   Sun, 02 Jun 2024
# 81   Sun, 02 Jun 2024
# 82   Sun, 02 Jun 2024
# 83   Sun, 02 Jun 2024
# 84   Sun, 02 Jun 2024
# 85   Sun, 02 Jun 2024
# 86   Sun, 02 Jun 2024
# 87   Sun, 02 Jun 2024
# 88   Sun, 02 Jun 2024
# 89   Sun, 02 Jun 2024
# 90   Sun, 02 Jun 2024
# 91   Sun, 02 Jun 2024
# 92   Sun, 02 Jun 2024
# 93   Sun, 02 Jun 2024
# 94   Sun, 02 Jun 2024
# 95   Sun, 02 Jun 2024
# 96   Sun, 02 Jun 2024
# 97   Sun, 02 Jun 2024
# 98   Sun, 02 Jun 2024
# 99   Sun, 02 Jun 2024
# 100  Sun, 02 Jun 2024
# 101  Sun, 02 Jun 2024
# 102  Sun, 02 Jun 2024
# 103  Sun, 02 Jun 2024
# 104  Sun, 02 Jun 2024
# 105  Sun, 02 Jun 2024
# 106  Sun, 02 Jun 2024
# 107  Sun, 02 Jun 2024
# 108  Sun, 02 Jun 2024
# 109  Sun, 02 Jun 2024
# 110  Sun, 02 Jun 2024
# 111  Sun, 02 Jun 2024
# 112  Sun, 02 Jun 2024
# 113  Sun, 02 Jun 2024
# 114  Sun, 02 Jun 2024
# 115  Sun, 02 Jun 2024
# 116  Sun, 02 Jun 2024
# 117  Sun, 02 Jun 2024
# 118  Sun, 02 Jun 2024
# 119  Sun, 02 Jun 2024
# 120  Sun, 02 Jun 2024
# 121  Sun, 02 Jun 2024
# 122  Sun, 02 Jun 2024
# 123  Sun, 02 Jun 2024
# 124  Sun, 02 Jun 2024
# 125  Sun, 02 Jun 2024
# 126  Sun, 02 Jun 2024
# 127  Sun, 02 Jun 2024
# 128  Sun, 02 Jun 2024
# 129  Sun, 02 Jun 2024
# 130  Sun, 02 Jun 2024
# 131  Sun, 02 Jun 2024
# 132  Sun, 02 Jun 2024
# 133  Sun, 02 Jun 2024
# 134  Sun, 02 Jun 2024
# 135  Sun, 02 Jun 2024
# 136  Sun, 02 Jun 2024
# 137  Sun, 02 Jun 2024
# 138  Sun, 02 Jun 2024
# 139  Sun, 02 Jun 2024
# 140  Sun, 02 Jun 2024
# 141  Sun, 02 Jun 2024
# 142  Sun, 02 Jun 2024
# 143  Sun, 02 Jun 2024
# 144  Sun, 02 Jun 2024
# 145  Sun, 02 Jun 2024
# 146  Sun, 02 Jun 2024
# 147  Sun, 02 Jun 2024
# 148  Sun, 02 Jun 2024
# 149  Sun, 02 Jun 2024
# 150  Sun, 02 Jun 2024
# 151  Sun, 02 Jun 2024
# 152  Sun, 02 Jun 2024
# 153  Sun, 02 Jun 2024
# 154  Sun, 02 Jun 2024
# 155  Sun, 02 Jun 2024
# 156  Sun, 02 Jun 2024
# 157  Sun, 02 Jun 2024
# 158  Sun, 02 Jun 2024
# 159  Sun, 02 Jun 2024
# 160  Sun, 02 Jun 2024
# 161  Sun, 02 Jun 2024

# %%
import sqlite3

# %%
import sqlite3
# Create a sqlite3 database
conn = sqlite3.connect('currency_rates.db')
c = conn.cursor()

# Push the data to the database
result.to_sql('currency', conn, if_exists='replace', index=False)

query = """
SELECT *
FROM currency
"""
import pandas as pd
old_data = pd.read_sql_query(query, conn)
new_data = pd.concat([old_data, result], ignore_index=True)

# %%
query = """
SELECT *
FROM currency
"""
import pandas as pd
old_data = pd.read_sql_query(query, conn)

# %%
old_data
# Out:
#     Currency_Code        Rate           Currency_Name              date
# 0             LBP  89500.0000          Lebanese Pound  Sun, 02 Jun 2024
# 1             IRR  42063.1818            Iranian Rial  Sun, 02 Jun 2024
# 2             VND  25469.2457         Vietnamese Đồng  Sun, 02 Jun 2024
# 3             SLL  22504.0936    Sierra Leonean Leone  Sun, 02 Jun 2024
# 4             LAK  21655.8461                 Lao Kip  Sun, 02 Jun 2024
# ..            ...         ...                     ...               ...
# 157           XDR      0.7552  Special Drawing Rights  Sun, 02 Jun 2024
# 158           JOD      0.7090         Jordanian Dinar  Sun, 02 Jun 2024
# 159           OMR      0.3845              Omani Rial  Sun, 02 Jun 2024
# 160           BHD      0.3760          Bahraini Dinar  Sun, 02 Jun 2024
# 161           KWD      0.3069           Kuwaiti Dinar  Sun, 02 Jun 2024
#
# [162 rows x 4 columns]
